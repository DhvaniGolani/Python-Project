# %%
# Loading the required libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# Libraries for ploting
import numpy as np
import os
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.offline as py
from plotly import tools
import numpy as np
import matplotlib
from plotly.offline import iplot
import warnings
warnings.filterwarnings("ignore")
import cufflinks as cf
cf.go_offline()
import plotly.io as pio
pio.renderers.default='colab'                         #set the rendering process of the graph on colab
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Fictional Heroes Analysis

# %%
# Importing CSV file to DataFrame format
marvel=pd.read_csv('/content/charcters_stats.csv')

# %%
# Number of rows and columns
marvel.shape
# Out:
# (420, 9)

# %%
# Top 5 rows of DataFrame
marvel.head()
# Out:
#               Name Alignment  Intelligence  ...  Power  Combat  Total
# 0       Alan Scott      good            63  ...     98      32    386
# 1            Amazo       bad            75  ...    100     100    575
# 2            Angel      good            63  ...     17      42    245
# 3  Angel Salvadore      good            38  ...     46      60    210
# 4       Animal Man      good            56  ...     73      80    389
#
# [5 rows x 9 columns]

# %%
# Last 5 rows of DataFrame
marvel.tail()
# Out:
#          Name Alignment  Intelligence  ...  Power  Combat  Total
# 415     Krish      good            60  ...     66      55    368
# 416    Ra-One       bad            50  ...     60      50    277
# 417     G-One      good            60  ...     50      50    272
# 418  Bahubali      good            70  ...     66      70    418
# 419      Hero      good            35  ...     56      33    214
#
# [5 rows x 9 columns]

# %%
# statistical data of all the characters
marvel.describe()
# Out:
#        Intelligence    Strength       Speed  ...       Power      Combat       Total
# count    420.000000  420.000000  420.000000  ...  420.000000  420.000000  420.000000
# mean      62.388095   41.052381   38.035714  ...   57.421429   60.521429  317.611905
# std       20.839524   32.189877   22.577074  ...   26.865901   23.131708  105.245409
# min        6.000000    1.000000    1.000000  ...    0.000000    6.000000   60.000000
# 25%       50.000000   10.000000   23.000000  ...   35.000000   42.000000  239.000000
# 50%       63.000000   32.000000   33.000000  ...   58.000000   64.000000  303.500000
# 75%       75.000000   73.000000   50.000000  ...   75.250000   80.000000  381.750000
# max      100.000000  100.000000  100.000000  ...  100.000000  100.000000  600.000000
#
# [8 rows x 7 columns]

# %%
# count not null cells for each column or row
marvel.count()
# Out:
# Name            420
# Alignment       420
# Intelligence    420
# Strength        420
# Speed           420
# Durability      420
# Power           420
# Combat          420
# Total           420
# dtype: int64

# %%
# Extract two columns form DataFrame
marvel[['Name','Strength']].head(12)
# Out:
#                Name  Strength
# 0        Alan Scott        80
# 1             Amazo       100
# 2             Angel        13
# 3   Angel Salvadore        10
# 4        Animal Man        48
# 5         Annihilus        80
# 6           Ant-Man        10
# 7        Ant-Man II        10
# 8      Anti-Monitor        90
# 9        Apocalypse       100
# 10         Aquababy        16
# 11          Aqualad        44

# %%
# Counts of unique values for Alignment
alignment=marvel['Alignment'].value_counts()

# %%
# Display Counts of unique values for Alignment
alignment
# Out:
# good       292
# bad        117
# neutral     11
# Name: Alignment, dtype: int64

# %%
# Create DataFrame for Counts of unique values for Alignment
data_plot=pd.DataFrame({'labels':alignment.index,'counts':alignment.values})

# %%
# Display DataFrame for Counts of unique values for Alignment
data_plot
# Out:
#     labels  counts
# 0     good     292
# 1      bad     117
# 2  neutral      11

# %%
#Pie Chart for Counts of unique values for Alignment
data_plot.iplot(kind='pie',labels='labels',values='counts',colors=['lightblue','lightgrey','lightcyan'],
                width=1,title='Percentage of superheroes, supervillains and neutral heroes')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ee12f64a-d804-4a42-a363-c64a631e3af3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ee12f64a-d804-4a42-a363-c64a631e3af3")) {
#                     Plotly.newPlot(
#                         'ee12f64a-d804-4a42-a363-c64a631e3af3',
#                         [{"labels": ["good", "bad", "neutral"], "marker": {"colors": ["rgba(173, 216, 230, 1.0)", "rgba(211, 211, 211, 1.0)", "rgba(224, 255, 255, 1.0)"], "line": {"width": 1}}, "name": "", "type": "pie", "values": [292, 117, 11]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": "Percentage of superheroes, supervillains and neutral heroes", "titlefont": {"color": "#4D5663"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ee12f64a-d804-4a42-a363-c64a631e3af3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#
#             </script>
#         </div>
# </body>
# </html>

# %% [markdown]
# # Superheroes Analysis

# %%
# DataFrame for Superheroes (Alignment = good)
good=marvel[marvel['Alignment']=="good"]

# %%
# Top 5 rows of DataFrame
good.head()
# Out:
#               Name Alignment  Intelligence  ...  Power  Combat  Total
# 0       Alan Scott      good            63  ...     98      32    386
# 2            Angel      good            63  ...     17      42    245
# 3  Angel Salvadore      good            38  ...     46      60    210
# 4       Animal Man      good            56  ...     73      80    389
# 6          Ant-Man      good           100  ...     32      32    225
#
# [5 rows x 9 columns]

# %%
# Last 5 rows of DataFrame
good.tail()
# Out:
#           Name Alignment  Intelligence  ...  Power  Combat  Total
# 414  Shaktiman      good            60  ...     56      25    285
# 415      Krish      good            60  ...     66      55    368
# 417      G-One      good            60  ...     50      50    272
# 418   Bahubali      good            70  ...     66      70    418
# 419       Hero      good            35  ...     56      33    214
#
# [5 rows x 9 columns]

# %%
# Sort Superheroes by their Speed
good.sort_values(by=['Speed'],ascending=False).head()
# Out:
#            Name Alignment  Intelligence  ...  Power  Combat  Total
# 269        Nova      good            38  ...    100      25    423
# 172     Impulse      good            50  ...     63      60    343
# 43   Black Bolt      good            75  ...    100      56    482
# 203      Krypto      good             9  ...     72      40    391
# 347    Stardust      good            88  ...    100      85    558
#
# [5 rows x 9 columns]

# %%
# Superheroes with speed greater than equal to 90
good[good['Speed']>=90]
# Out:
#                   Name Alignment  Intelligence  ...  Power  Combat  Total
# 43          Black Bolt      good            75  ...    100      56    482
# 135              Flash      good            63  ...     83      32    348
# 172            Impulse      good            50  ...     63      60    343
# 179     Jack of Hearts      good            63  ...     70      30    348
# 203             Krypto      good             9  ...     72      40    391
# 226  Martian Manhunter      good           100  ...    100      85    581
# 269               Nova      good            38  ...    100      25    423
# 288        Quicksilver      good            63  ...     57      56    364
# 312            Saitama      good           100  ...    100     100    600
# 347           Stardust      good            88  ...    100      85    558
# 358          Supergirl      good            94  ...     85      75    544
# 359           Superman      good           100  ...     94      85    579
# 369               Thor      good            69  ...    100      85    546
#
# [13 rows x 9 columns]

# %%
# Histogram for speed for good superheroes
plt.figure(figsize=(5,7))
plt.hist(good['Speed'])
plt.title("Distribution of speed")
plt.xlabel("Speed")
plt.show()

# %%
# Sort Superheroes by their Power
good.sort_values(by=['Power'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  ...  Power  Combat  Total
# 99          Deadman      good            50  ...    100      42    335
# 323     Shadow King      good            75  ...    100      75    389
# 116    Dr Manhattan      good            88  ...    100      42    399
# 396         Watcher      good           100  ...    100      56    492
# 111  Doctor Strange      good           100  ...    100      60    366
#
# [5 rows x 9 columns]

# %%
# Histogram for power for good superheroes
plt.figure(figsize=(5,7))
plt.hist(good['Power'])
plt.title("Distribution of Power")
plt.xlabel("Power")
plt.show()

# %%
# Sort Superheroes by their Total and store them
good_max_power=good.sort_values(by=['Total'],ascending=False)

# %%
# Display Top 5 rows
good_max_power.head()
# Out:
#                   Name Alignment  Intelligence  ...  Power  Combat  Total
# 312            Saitama      good           100  ...    100     100    600
# 226  Martian Manhunter      good           100  ...    100      85    581
# 359           Superman      good           100  ...     94      85    579
# 347           Stardust      good            88  ...    100      85    558
# 369               Thor      good            69  ...    100      85    546
#
# [5 rows x 9 columns]

# %%
# Display Last 5 rows
good_max_power.tail()
# Out:
#                Name Alignment  Intelligence  ...  Power  Combat  Total
# 289           Quill      good            38  ...     23      14    111
# 10         Aquababy      good            10  ...     37      14    103
# 405  Wyatt Wingfoot      good            10  ...      1      56     90
# 200    Kool-Aid Man      good            25  ...     10      14     85
# 137  Franklin Storm      good            38  ...      0      10     60
#
# [5 rows x 9 columns]

# %%
# Create DataFrame of superheroes 
df = pd.DataFrame(good_max_power)

# taking value of top 12 superheroes and their total
name = df['Name'].head(12)
total = df['Total'].head(12)

# Figure Size
fig, ax = plt.subplots(figsize =(15, 10))
 
# Horizontal Bar Plot
ax.barh(name, total)
# Remove axes splines
for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
# Add x, y gridlines
ax.grid(color ='grey',linestyle ='-.', linewidth = 0.5,)
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 12, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Superheroes Anaylysis',loc ='left')

# Show Plot
plt.show()

# %% [markdown]
# # SuperVillain Analysis

# %%
# DataFrame for Supervillains (Alignment = bad)
bad=marvel[marvel['Alignment']=="bad"]

# %%
# Display Top 5 rows
bad.head()
# Out:
#             Name Alignment  Intelligence  ...  Power  Combat  Total
# 1          Amazo       bad            75  ...    100     100    575
# 5      Annihilus       bad            75  ...     59      64    381
# 8   Anti-Monitor       bad            88  ...    100      90    496
# 9     Apocalypse       bad           100  ...    100      60    493
# 14      Arclight       bad            38  ...     52      70    288
#
# [5 rows x 9 columns]

# %%
# Display Last 5 rows
bad.tail()
# Out:
#                Name Alignment  Intelligence  ...  Power  Combat  Total
# 390          Walrus       bad            50  ...     11      20    167
# 393            Warp       bad            38  ...     63      50    212
# 398  Willis Stryker       bad            38  ...     41      60    206
# 412            Zoom       bad            50  ...     72      28    288
# 416          Ra-One       bad            50  ...     60      50    277
#
# [5 rows x 9 columns]

# %%
# Sort Supervillains by their Strength
bad.sort_values(by=['Strength'],ascending=False).head()
# Out:
#             Name Alignment  Intelligence  ...  Power  Combat  Total
# 1          Amazo       bad            75  ...    100     100    575
# 142  General Zod       bad            94  ...     94      95    579
# 9     Apocalypse       bad           100  ...    100      60    493
# 221        Magus       bad            88  ...    100      74    531
# 42    Black Adam       bad            88  ...     89      56    525
#
# [5 rows x 9 columns]

# %%
# Supervillains with strength greater than equal to 90
bad[bad['Strength']>=90]
# Out:
#                 Name Alignment  Intelligence  ...  Power  Combat  Total
# 1              Amazo       bad            75  ...    100     100    575
# 8       Anti-Monitor       bad            88  ...    100      90    496
# 9         Apocalypse       bad           100  ...    100      60    493
# 42        Black Adam       bad            88  ...     89      56    525
# 88   Cyborg Superman       bad            75  ...    100      80    540
# 95          Darkseid       bad            88  ...    100      95    506
# 105        Destroyer       bad            50  ...     90      70    461
# 115         Dormammu       bad            88  ...    100      80    546
# 128            Faora       bad            88  ...     87      90    535
# 142      General Zod       bad            94  ...     94      95    579
# 221            Magus       bad            88  ...    100      74    531
# 229            Match       bad            75  ...     90      70    498
# 232           Maxima       bad            75  ...     67      75    398
# 339   Solomon Grundy       bad             9  ...     78      30    323
# 357   Superboy-Prime       bad            94  ...    100      85    579
# 365           Thanos       bad            88  ...    100      80    485
#
# [16 rows x 9 columns]

# %%
# Histogram for Strength for bad Supervillains
plt.figure(figsize=(5,7))
plt.hist(bad['Strength'])
plt.title("Distribution of Strength")
plt.xlabel("Strength")
plt.show()

# %%
# Sort Supervillains by their Combat
bad.sort_values(by=['Combat'],ascending=False).head()
# Out:
#              Name Alignment  Intelligence  ...  Power  Combat  Total
# 1           Amazo       bad            75  ...    100     100    575
# 290  Ra's Al Ghul       bad           100  ...     27     100    329
# 310    Sabretooth       bad            55  ...     28     100    351
# 95       Darkseid       bad            88  ...    100      95    506
# 301     Rick Flag       bad            88  ...     19      95    264
#
# [5 rows x 9 columns]

# %%
# Histogram for Combat for bad Supervillains
plt.figure(figsize=(5,7))
plt.hist(bad['Combat'])
plt.title("Distribution of Combat")
plt.xlabel("Combat")
plt.show()

# %%
# Sort Supervillains by their Total and store them
bad_max_power=bad.sort_values(by=['Total'],ascending=False)

# %%
# Display Top 5 rows
bad_max_power.head()
# Out:
#                Name Alignment  Intelligence  ...  Power  Combat  Total
# 142     General Zod       bad            94  ...     94      95    579
# 357  Superboy-Prime       bad            94  ...    100      85    579
# 1             Amazo       bad            75  ...    100     100    575
# 115        Dormammu       bad            88  ...    100      80    546
# 113        Doomsday       bad            88  ...    100      90    545
#
# [5 rows x 9 columns]

# %%
# Display Last 5 rows
bad_max_power.tail()
# Out:
#          Name Alignment  Intelligence  ...  Power  Combat  Total
# 380  Two-Face       bad            88  ...      9      28    161
# 302   Riddler       bad           100  ...     10      14    160
# 334     Siren       bad            38  ...     55      28    157
# 286      Pyro       bad            38  ...     50      28    152
# 296  Red Mist       bad            25  ...     20      56    148
#
# [5 rows x 9 columns]

# %%
# Create DataFrame of Supervillains
df = pd.DataFrame(bad_max_power)

# taking value of top 12 supervillains and their total
name = df['Name'].head(12)
total = df['Total'].head(12)

# Figure Size
fig, ax = plt.subplots(figsize =(15, 10))
# Horizontal Bar Plot
ax.barh(name, total)
# Remove axes splines
for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
# Add x, y gridlines
ax.grid(color ='grey',linestyle ='-.', linewidth = 0.5,)
# Show top values
ax.invert_yaxis()
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 12, fontweight ='bold',
             color ='grey')
# Add Plot Title
ax.set_title('Supervillains Anaylysis',loc ='left')
# Show Plot
plt.show()

# %% [markdown]
# # Neutral Alignment heroes Analysis

# %%
# DataFrame for neutral heroes (Alignment = neutral)
neutral=marvel[marvel['Alignment']=="neutral"]

# %%
# Display Top 5 rows
neutral.head()
# Out:
#             Name Alignment  Intelligence  ...  Power  Combat  Total
# 41       Bizarro   neutral            75  ...     95      85    550
# 100     Deadpool   neutral            50  ...    100     100    395
# 103  Deathstroke   neutral            75  ...     36      90    366
# 139     Galactus   neutral           100  ...    100      70    553
# 190   Juggernaut   neutral            44  ...     74      70    430
#
# [5 rows x 9 columns]

# %%
# Display Last 5 rows
neutral.tail()
# Out:
#              Name Alignment  Intelligence  ...  Power  Combat  Total
# 292         Raven   neutral            50  ...     62      40    261
# 294      Red Hood   neutral            75  ...     24      95    257
# 313       Sandman   neutral            50  ...     62      56    387
# 367  The Comedian   neutral            63  ...     12      80    196
# 377          Toad   neutral            50  ...     49      28    275
#
# [5 rows x 9 columns]

# %%
# Sort neutral heroes by their Durability 
neutral.sort_values(by=['Durability'],ascending=False).head()
# Out:
#             Name Alignment  Intelligence  ...  Power  Combat  Total
# 41       Bizarro   neutral            75  ...     95      85    550
# 100     Deadpool   neutral            50  ...    100     100    395
# 103  Deathstroke   neutral            75  ...     36      90    366
# 139     Galactus   neutral           100  ...    100      70    553
# 190   Juggernaut   neutral            44  ...     74      70    430
#
# [5 rows x 9 columns]

# %%
# neutral heroes with durability greater than equal to 90
neutral[neutral['Durability']>=90]
# Out:
#             Name Alignment  Intelligence  ...  Power  Combat  Total
# 41       Bizarro   neutral            75  ...     95      85    550
# 100     Deadpool   neutral            50  ...    100     100    395
# 103  Deathstroke   neutral            75  ...     36      90    366
# 139     Galactus   neutral           100  ...    100      70    553
# 190   Juggernaut   neutral            44  ...     74      70    430
# 313      Sandman   neutral            50  ...     62      56    387
#
# [6 rows x 9 columns]

# %%
# Histogram for Durability for neutral heroes
plt.figure(figsize=(5,7))
plt.hist(neutral['Durability'])
plt.title("Distribution of Durability")
plt.xlabel("Durability")
plt.show()

# %%
# Sort neutral heroes by their Intelligence 
neutral.sort_values(by=['Intelligence'],ascending=False).head()
# Out:
#              Name Alignment  Intelligence  ...  Power  Combat  Total
# 139      Galactus   neutral           100  ...    100      70    553
# 41        Bizarro   neutral            75  ...     95      85    550
# 103   Deathstroke   neutral            75  ...     36      90    366
# 294      Red Hood   neutral            75  ...     24      95    257
# 367  The Comedian   neutral            63  ...     12      80    196
#
# [5 rows x 9 columns]

# %%
# Histogram for Intelligence for neutral heroes
plt.figure(figsize=(5,7))
plt.hist(neutral['Intelligence'])
plt.title("Distribution of Intelligence")
plt.xlabel("Intelligence")
plt.show()

# %%
# Sort neutral heroes by their Total and store them
neutral_max_power=neutral.sort_values(by=['Total'],ascending=False)

# %%
# Display all rows
neutral_max_power
# Out:
#              Name Alignment  Intelligence  ...  Power  Combat  Total
# 139      Galactus   neutral           100  ...    100      70    553
# 41        Bizarro   neutral            75  ...     95      85    550
# 190    Juggernaut   neutral            44  ...     74      70    430
# 100      Deadpool   neutral            50  ...    100     100    395
# 313       Sandman   neutral            50  ...     62      56    387
# 103   Deathstroke   neutral            75  ...     36      90    366
# 377          Toad   neutral            50  ...     49      28    275
# 292         Raven   neutral            50  ...     62      40    261
# 294      Red Hood   neutral            75  ...     24      95    257
# 222       Man-Bat   neutral            38  ...     33      30    239
# 367  The Comedian   neutral            63  ...     12      80    196
#
# [11 rows x 9 columns]

# %%
# Create DataFrame of neutral heroes
df = pd.DataFrame(neutral_max_power)

# taking value of top 12 neutral heroes and their total
name = df['Name']
total = df['Total']

# Figure Size
fig, ax = plt.subplots(figsize =(15, 10))
# Horizontal Bar Plot
ax.barh(name, total)
# Remove axes splines
for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
# Add x, y gridlines
ax.grid(color ='grey',linestyle ='-.', linewidth = 0.5,)

# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 12, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Neutral Heroes Anaylysis',loc ='left')
# Show Plot
plt.show()

# %% [markdown]
# # Box Plots for all the Characters

# %%
# Box Plot
marvel[['Strength','Intelligence','Power','Durability','Combat','Speed']].iplot(kind ='box')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5877e8ba-d954-4acd-98cb-cef6dcc1f2d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5877e8ba-d954-4acd-98cb-cef6dcc1f2d3")) {
#                     Plotly.newPlot(
#                         '5877e8ba-d954-4acd-98cb-cef6dcc1f2d3',
#                         [{"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(255, 153, 51, 1.0)"}, "name": "Strength", "orientation": "v", "type": "box", "y": [80, 100, 13, 10, 48, 80, 10, 10, 90, 100, 16, 44, 80, 13, 63, 82, 10, 63, 80, 10, 15, 11, 18, 53, 10, 53, 12, 18, 11, 53, 48, 28, 7, 80, 100, 90, 10, 12, 36, 10, 14, 95, 100, 67, 16, 10, 11, 10, 16, 13, 32, 10, 28, 28, 14, 8, 10, 83, 80, 10, 34, 10, 85, 75, 28, 10, 11, 28, 10, 48, 53, 10, 28, 19, 77, 100, 63, 13, 80, 10, 10, 10, 80, 9, 10, 83, 16, 53, 93, 10, 10, 10, 13, 32, 14, 100, 8, 4, 10, 10, 15, 10, 32, 30, 48, 95, 12, 80, 32, 16, 70, 10, 10, 80, 63, 95, 32, 80, 32, 10, 11, 8, 10, 63, 32, 81, 13, 85, 95, 28, 81, 8, 63, 8, 53, 10, 10, 10, 53, 100, 10, 5, 100, 55, 89, 10, 34, 100, 32, 12, 55, 85, 80, 90, 85, 12, 10, 38, 12, 28, 53, 10, 100, 8, 10, 100, 10, 10, 63, 13, 95, 32, 10, 28, 10, 23, 85, 63, 48, 55, 34, 80, 10, 38, 10, 80, 12, 10, 12, 8, 100, 38, 10, 48, 7, 10, 48, 90, 18, 38, 10, 34, 32, 80, 10, 5, 10, 10, 10, 10, 53, 51, 83, 57, 10, 55, 6, 36, 32, 80, 48, 100, 18, 32, 44, 28, 100, 85, 73, 95, 10, 10, 90, 10, 34, 10, 85, 62, 53, 10, 8, 28, 67, 32, 85, 10, 32, 10, 73, 10, 36, 67, 60, 73, 80, 63, 11, 10, 12, 85, 72, 80, 11, 10, 11, 52, 5, 18, 85, 60, 10, 85, 11, 85, 10, 28, 10, 80, 63, 10, 14, 70, 98, 8, 38, 16, 10, 14, 28, 10, 28, 4, 10, 16, 12, 88, 10, 11, 10, 38, 80, 11, 10, 11, 11, 8, 5, 10, 10, 10, 53, 10, 100, 75, 80, 70, 10, 53, 55, 10, 28, 52, 80, 12, 8, 12, 48, 100, 10, 10, 57, 100, 28, 80, 10, 8, 85, 32, 34, 93, 36, 18, 60, 38, 55, 42, 12, 85, 80, 40, 82, 10, 10, 80, 63, 1, 95, 100, 98, 100, 80, 10, 67, 60, 10, 100, 10, 14, 84, 100, 83, 32, 80, 81, 72, 32, 10, 34, 73, 10, 10, 80, 83, 80, 10, 57, 63, 4, 72, 22, 28, 80, 36, 10, 72, 8, 80, 32, 16, 32, 16, 32, 90, 100, 100, 10, 24, 53, 10, 10, 100, 10, 10, 23, 56, 66, 55, 50, 82, 50]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(55, 128, 191, 1.0)"}, "name": "Intelligence", "orientation": "v", "type": "box", "y": [63, 75, 63, 38, 56, 75, 100, 63, 88, 100, 10, 63, 63, 63, 38, 75, 50, 50, 50, 38, 50, 50, 63, 88, 50, 25, 69, 100, 88, 50, 88, 50, 10, 63, 88, 63, 38, 75, 63, 25, 63, 75, 88, 75, 75, 63, 50, 75, 88, 75, 63, 38, 50, 63, 69, 50, 38, 10, 63, 50, 50, 38, 56, 50, 100, 100, 50, 63, 38, 88, 63, 50, 50, 63, 75, 100, 63, 63, 88, 50, 88, 63, 50, 38, 63, 63, 63, 75, 75, 75, 63, 38, 75, 50, 75, 88, 38, 9, 63, 50, 50, 50, 69, 75, 50, 50, 50, 75, 100, 81, 90, 100, 63, 88, 8, 88, 88, 88, 38, 69, 63, 50, 38, 75, 50, 63, 38, 88, 88, 38, 50, 38, 38, 50, 50, 63, 63, 38, 63, 100, 63, 63, 94, 50, 81, 75, 50, 56, 50, 75, 75, 75, 38, 63, 50, 81, 63, 38, 50, 50, 63, 50, 63, 10, 63, 88, 56, 69, 63, 38, 63, 63, 50, 38, 69, 75, 100, 88, 75, 63, 6, 100, 75, 38, 88, 50, 75, 100, 63, 56, 44, 50, 50, 100, 25, 10, 25, 81, 75, 63, 25, 50, 63, 9, 100, 25, 100, 38, 38, 44, 75, 38, 88, 88, 50, 44, 38, 75, 63, 88, 50, 88, 38, 50, 63, 100, 100, 63, 75, 75, 63, 63, 75, 50, 75, 38, 88, 56, 75, 88, 63, 38, 63, 63, 63, 100, 75, 98, 50, 50, 50, 56, 63, 38, 63, 38, 63, 75, 75, 50, 50, 50, 75, 50, 88, 63, 63, 50, 100, 38, 50, 88, 75, 75, 75, 63, 38, 100, 50, 50, 69, 30, 88, 100, 63, 50, 38, 81, 63, 38, 100, 63, 50, 63, 75, 50, 25, 81, 75, 75, 25, 88, 100, 88, 81, 69, 50, 75, 38, 75, 55, 75, 100, 50, 75, 63, 81, 75, 88, 88, 38, 50, 75, 75, 88, 63, 63, 69, 63, 50, 50, 63, 50, 75, 38, 38, 50, 50, 50, 9, 75, 38, 75, 63, 88, 50, 50, 88, 50, 50, 81, 69, 75, 63, 63, 8, 75, 94, 94, 100, 88, 75, 75, 60, 38, 88, 38, 63, 75, 69, 75, 50, 63, 38, 38, 63, 100, 50, 56, 63, 88, 50, 88, 50, 63, 75, 63, 10, 100, 63, 50, 63, 88, 38, 38, 63, 100, 50, 38, 56, 38, 55, 75, 75, 88, 10, 75, 88, 88, 50, 50, 75, 50, 30, 60, 60, 50, 60, 70, 35]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(50, 171, 96, 1.0)"}, "name": "Power", "orientation": "v", "type": "box", "y": [98, 100, 17, 46, 73, 59, 32, 32, 100, 100, 37, 76, 65, 28, 52, 62, 72, 55, 69, 38, 69, 87, 35, 51, 60, 21, 42, 37, 36, 48, 35, 7 ...

# %% [markdown]
# # Battle

# %%
# taking input from the user
sp1=input("Enter character name 1: ")
sp2=input("Enter character name 2: ")

# Create list of all Names from DataFrame
sp=list(marvel['Name'])

# Loop for Lowercase all Names of the characters 
for i in range(len(sp)): 
  sp[i] = sp[i]. lower()   

# Loop for validation of names entered by the user 
if (sp1.lower() in sp) and (sp2.lower() in sp):

  # Extract data of both characters and create a dataframe
  superhero1=marvel[marvel['Name']==sp1.title()]
  df1=pd.DataFrame(superhero1)
  superhero2=marvel[marvel['Name']==sp2.title()]
  df2=pd.DataFrame(superhero2)

  # Merge DataFrames of both the characters
  c=[df1,df2]
  compare=pd.concat(c)

  # Display DataFrame of both the characters
  print('\n')
  display(compare)
  print('\n')

  # Plot Graph of both the characters
  plt.figure(figsize=(4,5))
  plt.bar(list(compare['Name']),list(compare['Total']),color=["black","red"])
  plt.show()
  print('\n')

  # Comparing the value of both the characters for the Battle!!
  sp1_total=superhero1.Total.item()
  sp2_total=superhero2.Total.item()
  if sp1_total>sp2_total:
    print(superhero1.Name.item() , "Won the Battle!!!")
  elif sp2_total>sp1_total:
    print(superhero2.Name.item() , "Won the Battle!!!")
  else:
    print("No one wins the Battle!!!")

else:
  print("Enter valid details!")
# Out:
# Enter character name 1: GoKu
# Enter character name 2: ThaNos
#        Name Alignment  Intelligence  Strength  ...  Durability  Power  Combat  Total
# 147    Goku      good            56       100  ...          90    100     100    521
# 365  Thanos       bad            88       100  ...         100    100      80    485
#
# [2 rows x 9 columns]
# Goku Won the Battle!!!
